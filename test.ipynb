# %%
import numpy as np
import nnfs
import matplotlib.pyplot as plt
from library import *
import math
from nnfs.datasets import spiral_data, vertical_data
nnfs.init()

# %%
x = np.arange(0, 4,0.03)
y = np.sin(3.14 * x)
plt.style.use('dark_background')
plt.scatter(x, y)
plt.show()
